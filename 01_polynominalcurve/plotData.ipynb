# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,2]
w = fitdata(x,t,M = 9)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.39930825e+01 -1.82275866e-01  3.12097062e-03 -4.21687980e-05
#   3.02339910e-07 -5.69575254e-10 -5.82409629e-12  4.05533872e-14
#  -9.90235946e-17  8.67983970e-20]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18
#  1.68151254e+21 7.56680643e+23]
# predict_height = : 951.8348890327034

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,1]
w = fitdata(x,t,M = 9)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.69982702e+01 -3.87016537e-02 -2.45991560e-03  7.29560978e-05
#  -1.00819132e-06  7.84627980e-09 -3.59927375e-11  9.62790300e-14
#  -1.38703684e-16  8.30772397e-20]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18
#  1.68151254e+21 7.56680643e+23]
# predict_height = : 114.38284451125946

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,3]
w = fitdata(x,t,M = 9)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.39968084e+01 -1.58111728e-01  2.51113896e-03 -2.61307137e-05
#   7.53625909e-08  1.04204591e-09 -1.13221135e-11  4.68002092e-14
#  -9.08090386e-17  6.85338099e-20]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18
#  1.68151254e+21 7.56680643e+23]
# predict_height = : 412.78504851954494

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,3]
w = fitdata(x,t,M = 8)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.40019723e+01 -1.64726399e-01  3.11622228e-03 -4.65950810e-05
#   4.19814148e-07 -2.20238602e-09  6.54198713e-12 -1.01650143e-14
#   6.40614586e-18]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18
#  1.68151254e+21]
# predict_height = : 11.309946165831207

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,2]
w = fitdata(x,t,M = 8)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.39988358e+01 -1.90645693e-01  3.88725973e-03 -6.80866785e-05
#   7.38587259e-07 -4.67865211e-09  1.68008317e-11 -3.15932629e-14
#   2.40998405e-17]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18
#  1.68151254e+21]
# predict_height = : 443.3635831847205

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,1]
w = fitdata(x,t,M = 8)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.70100378e+01 -4.67582807e-02 -1.72621863e-03  4.81477345e-05
#  -5.90637460e-07  3.91332286e-09 -1.43376331e-11  2.72251430e-14
#  -2.08585094e-17]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18
#  1.68151254e+21]
# predict_height = : -372.2892027693888

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,1]
w = fitdata(x,t,M = 7)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.70402293e+01 -7.13954244e-02 -8.68259097e-06  3.88937038e-06
#  -3.45231000e-08  1.44238251e-10 -2.99484808e-13  2.46465725e-16]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18]
# predict_height = : 17.626939043231687

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,2]
w = fitdata(x,t,M = 7)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.39639425e+01 -1.62181162e-01  1.90283307e-03 -1.69507629e-05
#   9.60549217e-08 -3.23866378e-10  5.81209778e-13 -4.22204229e-16]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18]
# predict_height = : -7.144029897422115

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,3]
w = fitdata(x,t,M = 7)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.39926953e+01 -1.57160226e-01  2.58872922e-03 -3.30022906e-05
#   2.49018157e-07 -1.04481013e-09  2.23053669e-12 -1.87921875e-15]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18]
# predict_height = : -108.44261091092358

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,3]
w = fitdata(x,t,M = 10)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.34708078e+01 -1.63928524e-01  3.86667000e-03 -8.53408993e-05
#   1.36593431e-06 -1.51176264e-08  1.11664709e-10 -5.30242407e-13
#   1.53579528e-15 -2.45145441e-18  1.64517537e-21]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18
#  1.68151254e+21 7.56680643e+23 3.40506289e+26]
# predict_height = : 3562.2956736509223

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,2]
w = fitdata(x,t,M = 10)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.35991588e+01 -1.86599458e-01  4.13207656e-03 -8.63365525e-05
#   1.26504338e-06 -1.26239226e-08  8.59183543e-11 -3.89894053e-13
#   1.11435006e-15 -1.79300083e-18  1.22722845e-21]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18
#  1.68151254e+21 7.56680643e+23 3.40506289e+26]
# predict_height = : 3301.2482561832876

# %%
import matplotlib.pyplot as plt
def plotData(x1,t1,x2,t2,x3=None,t3=None,legend=[]):
#plot every thing
    p1 = plt.plot(x1,t1,'bo')  #training data
    p2 = plt.plot(x2,t2,'g')  # true value
    if (x3 is not None):
        p3 = plt.plot(x3,t3,'r')
#add title, legend and axes labels
    plt.ylabel('t')
    plt.xlabel('x')
    if (x3 is None):
        plt.legend((p1[0],p2[0]),legend)
    else :
        plt.legend((p1[0],p2[0],p3[0]),legend)
import numpy as np
def fitdata(x,t,M):
    '''fitdata(x,t,M): Fit a polynominal of order M to the data (x,t) '''
    X = np.array([x**m for m in range(M+1)]).T
    w = np.linalg.inv(X.T@X)@X.T@t
    return w
#Load Data
beerData = np.loadtxt('/Users/mac/FML/LectureNotes/01_PolynomialCurveFitting/beer_foam.dat.txt')
plt.scatter(beerData[:,0],beerData[:,1],color = 'red')
plt.scatter(beerData[:,0],beerData[:,2],color = 'blue')
plt.scatter(beerData[:,0],beerData[:,3],color = 'orange')
# then we can fit the data using the polynominal curve fitting method we thrived
x = beerData[:,0]
t = beerData[:,1]
w = fitdata(x,t,M = 10)
print("w = :",w)  # w here are the parameters of the plolynominal curve model in order of 9
#                                                            #
# so in this function M = 9 , N = 15 , X belong to R(9+1*15) #
#                                                            #
#Now lets use the weight(w parameter 参数/权重)in test
xrange = np.arange(beerData[0,0],beerData[beerData.shape[0]-1,0],0.001)  #get equally spaced points in the xrange
X = np.array([xrange**m for m in range(w.size)]).T
esty = X@w #compute the predicted value
plotData(x,t,xrange,esty,legend=['Training Data','Estimated\nPlolynominal'])
#What will the foam height be at t = __?
# Initialize 't' as float so below type is correct
t_predict = np.float64(450)
x_test = np.array([t_predict**m for m in range(w.size)]).T
print("x_test = :",x_test)
predict_height = x_test@w
print("predict_height = :",predict_height)
# Out:
# w = : [ 1.47905675e+01  1.00188188e-02 -5.25685035e-03  1.88898032e-04
#  -3.53069416e-06  3.94335759e-08 -2.76409784e-10  1.22434004e-12
#  -3.31866094e-15  5.00971091e-18 -3.21643050e-21]
# x_test = : [1.00000000e+00 4.50000000e+02 2.02500000e+05 9.11250000e+07
#  4.10062500e+10 1.84528125e+13 8.30376562e+15 3.73669453e+18
#  1.68151254e+21 7.56680643e+23 3.40506289e+26]
# predict_height = : -6042.89357547625
